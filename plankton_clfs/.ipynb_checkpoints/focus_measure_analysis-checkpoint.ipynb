# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

predicted_labels = np.load("./laps_nobg_100/predictions.npy")
#predicted_labels = np.argmax(predictions, axis=1)

real_labels = np.load("./laps_nobg_100/real_labels.npy")

measures = np.load("focus_valid_laps.npy")

data = pd.DataFrame({'real':real_labels, 'predicted':predicted_labels, 'lapv':measures[:,0], 'lapm':measures[:,1], 'teng':measures[:,2]})

data
# Out:
#          lapm      lapv  predicted  real      teng
# 0    0.048364  0.021300          2     3  0.568961
# 1    0.043574  0.003948         13     7  0.112697
# 2    0.068513  0.012549         17    17  0.038338
# 3    0.059097  0.013817          0     1  0.195713
# 4    0.039253  0.005078         17    17  0.142213
# 5    0.024334  0.001220          6     6  0.071972
# 6    0.053925  0.004961         19     6  0.142350
# 7    0.052557  0.007729          3     3  0.236430
# 8    0.031889  0.003348         13    13  0.157160
# 9    0.049395  0.009363         10    10  0.147017
# 10   0.052955  0.009796          2     2  0.239605
# 11   0.034680  0.005942          1     0  0.232752
# 12   0.027106  0.002508         17    17  0.117086
# 13   0.032181  0.002860         13    13  0.085038
# 14   0.040425  0.003280          7     7  0.049569
# 15   0.022014  0.004079         15    15  0.339263
# 16   0.038706  0.006439         11    16  0.309844
# 17   0.040542  0.002701          8     8  0.050338
# 18   0.041229  0.011043          6     6  0.554307
# 19   0.044446  0.007990         17    14  0.244105
# 20   0.039279  0.003427          8     7  0.052481
# 21   0.045375  0.004949         10    10  0.109875
# 22   0.035452  0.002530         12    12  0.157983
# 23   0.032793  0.003562         11    11  0.162328
# 24   0.027774  0.002214         13    13  0.133867
# 25   0.025494  0.001697          7    13  0.079792
# 26   0.034993  0.002744          2     2  0.141493
# 27   0.019647  0.001486          9     9  0.058733
# 28   0.082776  0.019145         17    17  0.169542
# 29   0.030707  0.004496         19    19  0.090840
# ..        ...       ...        ...   ...       ...
# 488  0.039725  0.002688          8     7  0.046439
# 489  0.036449  0.006222          4     5  0.289097
# 490  0.034796  0.014647         17    17  0.217276
# 491  0.010150  0.003081          9     9  0.412043
# 492  0.054962  0.010443          2     2  0.147629
# 493  0.048170  0.004859         11    11  0.088767
# 494  0.039163  0.005209         12     1  0.158315
# 495  0.038300  0.002355         13    13  0.085116
# 496  0.074237  0.009193         19    19  0.068444
# 497  0.026904  0.007033          6     6  0.213621
# 498  0.030091  0.002651         11    11  0.145873
# 499  0.038695  0.009241          2     2  0.337460
# 500  0.026772  0.001823         12    12  0.044942
# 501  0.030619  0.002484          4     3  0.157648
# 502  0.055815  0.026944         16    16  0.262412
# 503  0.033097  0.002429         13    13  0.070970
# 504  0.055131  0.008242          2     2  0.218495
# 505  0.030388  0.002066         12    12  0.069620
# 506  0.054094  0.005975         19    19  0.081262
# 507  0.026093  0.003251         13    13  0.111614
# 508  0.050741  0.009263         14    17  0.035775
# 509  0.029363  0.001719          7     7  0.075311
# 510  0.148057  0.049697          6     6  0.352849
# 511  0.023821  0.001567          7     7  0.054232
# 512  0.081599  0.010898         17    17  0.203039
# 513  0.043870  0.004734          6     6  0.234584
# 514  0.031168  0.001979          7     8  0.060604
# 515  0.034523  0.006046         12    12  0.218011
# 516  0.037906  0.002708          7     8  0.046640
# 517  0.033232  0.002003         12     0  0.084551
#
# [518 rows x 5 columns]

# %%
true_false = np.zeros(len(real_labels), dtype=int)
for i in range(len(real_labels)):
    if predicted_labels[i] == real_labels[i]:
        true_false[i] = 1
measures_log = np.log(measures)

# %%
f, a = plt.subplots(1,20, sharex=False, sharey=True)

for i in range(20):
    box_true = data[data['predicted'] == i][data['real'] == i]['lapv']
    box_false = data[data['predicted'] != i][data['real'] == i]['lapv']
    a[i].boxplot([box_true, box_false], widths=1, labels=['+', '-'])
    a[i].set_title(i)
    
f.subplots_adjust(hspace=0)
plt.show()
# Out:
# C:\Users\mariv\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\mariv\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\mariv\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
fi, a = plt.subplots()
a.boxplot([box_true_0, box_false_0, box_true_1, box_false_1,box_true_2, box_false_2])
plt.show()
# Out:
# C:\Users\mariv\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
fig, ax = plt.subplots()
plt.scatter(measures[:,0], measures[:,1], c=true_false, s=0.5, cmap='bwr_r')
plt.colorbar()
ax.set_xlabel('Variance of Laplacian')
ax.set_ylabel('Modified Laplacian')

# %%
fig1, ax1 = plt.subplots()
plt.scatter(measures[:,0], measures[:,2], c=true_false, s=0.5, cmap='bwr_r')
plt.colorbar()
ax1.set_xlabel('Variance of Laplacian')
ax1.set_ylabel('Tenengrad')

# %%
fig2, ax2 = plt.subplots()
plt.scatter(measures[:,1], measures[:,2], c=true_false, s=0.5, cmap='bwr_r')
plt.colorbar()
ax2.set_xlabel('Modified Laplacian')
ax2.set_ylabel('Tenengrad')

# %%
fig3, ax3 = plt.subplots()
plt.scatter(measures[:,0], true_false, s=0.6)

ax3.set_xlabel('Variance of Laplacian')
ax3.set_ylabel('Predições negativas e positivas')

# %%
fig3, ax3 = plt.subplots()
plt.scatter(measures[:,1], true_false, s=0.5)

ax3.set_xlabel('Modified Laplacian')
ax3.set_ylabel('Predições positivas')

# %%
fig3, ax3 = plt.subplots()
plt.scatter(measures[:,2], true_false, s=0.5)

ax3.set_xlabel('Tenengrad')
ax3.set_ylabel('Predições positivas')
